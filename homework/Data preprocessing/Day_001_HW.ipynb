# %% [markdown]
# <h2>作業 1:</h2><p>請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：</p>

# %% [markdown]
# <p>Q :</p>
# <ol>
#     <li>你選的這組資料為何重要 ?</li>
#     <li>資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?</li>
#     <li>蒐集而來的資料型態為何?</li>
#     <li>這組資料想解決的問題如何評估?</li>
# </ol>

# %% [markdown]
# <p>A :</p>
#
# <ol>
#     <p>所選 Dataset 為 : <a target="_blank" href="https://www.kaggle.com/lava18/google-play-store-apps#googleplaystore.csv">Google Play Store Apps</a></p>
#     <li>這組資料可以幫助我們分析使用者在 Google Store 的 Apps 使用習慣，我們可以針對這項資料去規劃未來 Apps 的開發方向及預期 Apps 的市場</li>
#     <li>透過 Web scrape 的方式蒐集各項 Apps 的種類、排名、下載次數等資料</li>
#     <li>以 CSV 的方式儲存</li>
#     <li>針對這數據我們可以從中分析出使用者 Apps 的使用習慣，得到一個模型，我們就可評估這項模型的準確性。</li>
# </ol>

# %% [markdown]
# <h2>作業 2:</h2><p>想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：</p>

# %% [markdown]
# <p>Q :</p>
# <ol>
#     <li>核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)</li>
#     <li>資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)?</li>
#     <li>蒐集而來的資料型態為何?</li>
#     <li>你要回答的問題，其如何評估 (tips：你的假設如何驗證)?</li>
# </ol>

# %% [markdown]
# <p>A :</p>
# <ol>
#     <li>提升業績: 整體營收上升</li>
#     <li><p>所需資料:</p> 載客時間、載客地點、載客目的地、載客性別、載客數量、載客年齡<p>資料如何蒐集:</p>手機app、車隊司機紀錄</li>
#     <li>json檔</li>
#     <li>從資料中找出高獲利的載客族群，去驗證和現實狀況是否相同</li>
# </ol>

# %% [markdown]
# ## 作業 3: 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum(pow(y-yp,2))/len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 233.036
# The Mean absolute error is 12.512
